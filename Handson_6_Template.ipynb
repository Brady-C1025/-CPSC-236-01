# %% [markdown]
# # Dictionaries
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 12.1 Champion Counter
# Create a program that reads a text file that contains a list of FIFA World Cup champions and determines the country that has won the most championships.
#
# ### Console:
# ```powershell
# Country	        Wins	Years
# =======	        ====	=====
# Argentina       2       1978, 1986
# Brazil	        5       1958, 1962, 1970, 1994, 2002
# England	        1       1966
# France	        1       1998
# Germany	        4       1954, 1974, 1990, 2014
# Italy	        4       1934, 1938, 1982, 2006
# Spain	        1       2010
# Uruguay	        2       1930, 1950
# ```
#
# ### Specifications:
# - Use the attached text file named `world_cup_champions.txt` that contains data like this:
# ```powershell
# Year,Country,Coach,Captain
# 1930,Uruguay,Alberto Suppici,José Nasazzi
# 1934,Italy,Vittorio Pozzo,Gianpiero Combi
# 1938,Italy,Vittorio Pozzo,Giuseppe Meazza
# ...
# ```
# - When the program starts, it should read the text file and use a dictionary to store the required data using the name of each country that has won the World Cup as the key.
# - The program should compile the data shown above and display the countries alphabetically.

# %%
wins = {}
with open('world_cup_champions.txt', 'r') as file:
    file.readline()
    for line in file:
        data = line.split(',')
        data[3] = data[3].rstrip('\n')

        Year = data[0]
        Country = data[1]
        Coach = data[2]
        Captain = data[3]

        if Country not in wins:
            wins[Country] = [1,[Year]]
        else:
            wins[Country][0] += 1
            wins[Country][1].append(Year)

wins = dict(sorted(wins.items()))

print(" Country        Wins	  Years\n =======        ====      =====")
for country in wins:
    print(f"{country:<10}    | {wins[country][0]:^5} |  {wins[country][1]}")
# Out:
#  Country        Wins	  Years
#  =======        ====      =====
# Argentina     |   2   |  ['1978', '1986']
# Brazil        |   5   |  ['1958', '1962', '1970', '1994', '2002']
# England       |   1   |  ['1966']
# France        |   1   |  ['1998']
# Germany       |   4   |  ['1954', '1974', '1990', '2014']
# Italy         |   4   |  ['1934', '1938', '1982', '2006']
# Spain         |   1   |  ['2010']
# Uruguay       |   2   |  ['1930', '1950']

# %% [markdown]
# ## 12.2 Monthly Sales
# Create a program that allows you to view and edit the sales amounts for each month of the current year.
#
# ### Console:
# ```powershell
# Monthly Sales program
#
# COMMAND MENU
# view	- View sales for specified month
# edit	- Edit sales for specified month
# totals - View sales summary for year
# exit	- Exit program
#
# Command: view
# Three-letter Month: jan
# Sales amount for Jan is 14,317.00.
#
# Command: edit
# Three-letter Month: jan
# Sales Amount: 15293
# Sales amount for Jan is 15,293.00.
#
# Command: totals
# Yearly total: 67,855.00
# Monthly average: 5,654.58
#
# Command: view
# Three-letter Month: july
# Invalid three-letter month.
#
# Command: exit Bye!
# ```
#
# ### Specifications:
# - Use the attached text file named `monthly_sales.txt` that consists of rows that contain three-letter abbreviations for the month and the monthly sales.
# - The program should read the file and store the sales data for each month in a dictionary with the month abbreviation as the key for each item.
# - Whenever the sales data is edited, the program should write the changed data to the text file.

# %%
def CommandMenu():
    print("\nCOMMAND MENU\nview    -  View sales for specified month\nedit	- Edit sales for specified month\ntotals	- View sales summary for year\nexit	- Exit program")
    return str(input("Command: "))

def LoadMonthlySales():
    print("")
    monthly_sales_data = {}
    with open("monthly_sales.txt", 'r') as file:
        for line in file:
            data = line.split()
            monthly_sales_data[data[0]] = data[1]
    return monthly_sales_data

def edit(monthly_sales_data):
    month = input("Three Letter Month: ")
    if month not in monthly_sales_data:
        print("Enter a valid three letter month abbreviation")
        return 0
    else:
        monthly_sales_data[month] = int(input("Sales Amount: "))
        with open("monthly_sales.txt", 'w') as file:
            for month in monthly_sales_data:
                file.write(month+'\t'+str(monthly_sales_data[month])+'\n')

def view(monthly_sales_data):
    month = input("Three Letter Month: ")
    if month not in monthly_sales_data:
        print("Enter a valid three letter month abbreviation")
        return 0
    else:
        print(f"Sales amount for {month} is {monthly_sales_data[month]}.")

def totals(monthly_sales_data):
    year_total = 0
    for month in monthly_sales_data:
        year_total += int(monthly_sales_data[month])
    monthly_average = round(year_total / 12, 2)

    print(f"Yearly Total: {year_total}")
    print(f"Monthly Average: {monthly_average}")
    
def main():
    print("Monthly Sales program")
    while True:
        match CommandMenu():
            case "view":
                view(LoadMonthlySales())
            case "edit":
                edit(LoadMonthlySales())
            case "totals":
                totals(LoadMonthlySales())
            case "exit":
                break
            case _:
                print("Enter a valid selection")
    print("Bye")

main()### CODE HERE ###
# Out:
# Monthly Sales program
#
# COMMAND MENU
# view    -  View sales for specified month
# edit	- Edit sales for specified month
# totals	- View sales summary for year
# exit	- Exit program
# Command:  totals
# Yearly Total: 52982
# Monthly Average: 4415.17
#
# COMMAND MENU
# view    -  View sales for specified month
# edit	- Edit sales for specified month
# totals	- View sales summary for year
# exit	- Exit program
# Command:  exit
# Bye
